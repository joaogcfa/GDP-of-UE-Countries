# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
paises_ue=["France", "Germany", "Belgium", "Italy", "Luxembourg", "Netherlands", "Denmark", "Ireland", "United Kingdom", "Greece", "Portugal", "Spain", "Austria", "Finland", "Sweden", "Hungary", "Cyprus", "Czech Republic", "Estonia", "Latvia", "Lithuania", "Malta", "Poland", "Slovakia", "Slovenia", "Bulgaria", "Romania", "Croatia"]
print(len(paises_ue))
# Out:
# 28

# %%
d1= pd.read_excel("income_per_person_gdppercapita_ppp_inflation_adjusted.xlsx")
income=d1.set_index("country")
income.head()
# Out:
#              1800  1801  1802  1803  1804  1805  1806  1807  1808  1809  \
# country
# Afghanistan   603   603   603   603   603   603   603   603   603   603
# Albania       667   667   667   667   667   668   668   668   668   668
# Algeria       715   716   717   718   719   720   721   722   723   724
# Andorra      1200  1200  1200  1200  1210  1210  1210  1210  1220  1220
# Angola        618   620   623   626   628   631   634   637   640   642
#
#              ...     2031   2032   2033   2034   2035   2036   2037   2038  \
# country      ...
# Afghanistan  ...     2420   2470   2520   2580   2640   2700   2760   2820
# Albania      ...    18500  18900  19300  19700  20200  20600  21100  21500
# Algeria      ...    15600  15900  16300  16700  17000  17400  17800  18200
# Andorra      ...    73200  74800  76400  78100  79900  81600  83400  85300
# Angola       ...     6270   6410   6550   6700   6850   7000   7150   7310
#
#               2039   2040
# country
# ...

# %%
lista=[]
for pais in paises_ue:
    for mun in d1["country"]:
        if pais == mun:
            lista.append(pais)
# for e in d1["country"]:
#     if e=="Brazil":
#         lista.append(e)
print(lista)
print(len(lista))
# Out:
# ['France', 'Germany', 'Belgium', 'Italy', 'Luxembourg', 'Netherlands', 'Denmark', 'Ireland', 'United Kingdom', 'Greece', 'Portugal', 'Spain', 'Austria', 'Finland', 'Sweden', 'Hungary', 'Cyprus', 'Czech Republic', 'Estonia', 'Latvia', 'Lithuania', 'Malta', 'Poland', 'Slovenia', 'Bulgaria', 'Romania', 'Croatia']
# 27

# %%
incomep=income.loc[["Germany","United Kingdom", "Greece", "France", "Japan", "Brazil", "China", "Mexico"]]
incomep=incomep.transpose()
incomep
# Out:
# country  Germany  United Kingdom  Greece  France  Japan  Brazil  China  Mexico
# 1800        1640            3430    1370    1800   1050    1110    984    1380
# 1801        1650            3440    1370    1810   1050    1110    984    1380
# 1802        1660            3450    1380    1810   1050    1110    984    1380
# 1803        1670            3340    1380    1810   1050    1110    984    1380
# 1804        1690            3290    1380    1820   1060    1110    984    1380
# 1805        1700            3440    1380    1820   1060    1110    984    1380
# 1806        1710            3380    1390    1820   1060    1110    984    1380
# 1807        1720            3550    1390    1830   1060    1110    984    1380
# 1808        1730            3340    1390    1830   1060    1110    984    1380
# 1809        1750            3400    1390    1830   1060    1110    985    1380
# 1810        1760            3570    1390    1840   1060    1110    985    1380
# ...

# %%
faixa = (incomep.index >= 1949) & (incomep.index <= 2000)
incomep[faixa].head(30)
# Out:
# country  Germany  United Kingdom  Greece  France  Japan  Brazil  China  Mexico
# 1949        6100           10900    3690    7370   2420    2930    530    4110
# 1950        7230           11200    3780    7920   2580    3030    536    4410
# 1951        7860           11500    4060    8310   2760    3080    583    4620
# 1952        8540           11400    4040    8450   3060    3190    632    4670
# 1953        9220           11800    4540    8630   3210    3230    694    4540
# 1954        9900           12200    4630    9010   3330    3370    696    4860
# 1955       11000           12600    4930    9460   3520    3550    708    5130
# 1956       11700           12700    5300    9920   3700    3520    738    5330
# 1957       12300           12800    5600   10500   3900    3670    782    5570
# 1958       12800           12800    5800   10700   4060    3940    892    5710
# 1959       13700           13200    5950   10900   4360    4190    961    5710
# ...

# %%
gincome=(incomep[faixa]).diff()
gincome.head()
# Out:
# country  Germany  United Kingdom  Greece  France  Japan  Brazil  China  Mexico
# 1949         NaN             NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 1950      1130.0           300.0    90.0   550.0  160.0   100.0    6.0   300.0
# 1951       630.0           300.0   280.0   390.0  180.0    50.0   47.0   210.0
# 1952       680.0          -100.0   -20.0   140.0  300.0   110.0   49.0    50.0
# 1953       680.0           400.0   500.0   180.0  150.0    40.0   62.0  -130.0

# %%
world=income.transpose()
faixa2 = (world.index >= 1949) & (world.index <= 2000)
world[faixa2].head()
world_gdp=world[faixa2].diff()
world_groth=world_g.transpose().mean()

# %%
plt.plot(gincome["United Kingdom"]/100, label="UK")
plt.plot(world_groth/100, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(gincome["France"]/100, label="França")
plt.plot(world_groth/100, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(gincome["Germany"]/100, label="Alemanha")
plt.plot(world_groth/100, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(gincome["Greece"]/100, label="Grécia")
plt.plot(world_groth/100, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(gincome["Japan"]/100, label="Japão")
plt.plot(world_groth/100, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(gincome["Brazil"]/100, label="Brasil")
plt.plot(world_groth/100, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(gincome["Mexico"]/100, label="Mexico")
plt.plot(world_groth/100, label="world")
plt.grid()
plt.legend()
