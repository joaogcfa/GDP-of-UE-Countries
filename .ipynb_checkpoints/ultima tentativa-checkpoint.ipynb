# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
paises_ue=["France", "Germany", "Belgium", "Italy", "Luxembourg", "Netherlands", "Denmark", "Ireland", "United Kingdom", "Greece", "Portugal", "Spain", "Austria", "Finland", "Sweden", "Hungary", "Cyprus", "Czech Republic", "Estonia", "Latvia", "Lithuania", "Malta", "Poland", "Slovak Republic", "Slovenia", "Bulgaria", "Romania", "Croatia"]

# %%
d1= pd.read_excel("gdp_total_yearly_growth.xlsx")
income=d1.set_index("country")
income
# Out:
#                           1801    1802    1803    1804    1805    1806  \
# country
# Afghanistan                NaN     NaN     NaN     NaN     NaN     NaN
# Albania                 0.4180  0.4180  0.4180  0.4180  0.4180  0.4180
# Algeria                 0.3560  0.3560  0.3560  0.3560  0.3560  0.3560
# Andorra                 0.1660  0.1660  0.1660  0.1660  0.1660  0.1660
# Angola                  0.4250  0.4250  0.4250  0.4250  0.4250  0.4250
# Antigua and Barbuda        NaN     NaN     NaN     NaN     NaN     NaN
# Argentina                  NaN     NaN     NaN     NaN     NaN     NaN
# Armenia                    NaN     NaN     NaN     NaN     NaN     NaN
# Australia              -0.0331 -0.0331 -0.0332 -0.0329 -0.0330 -0.0330
# Austria                 0.6380  0.6380  0.6380  0.6380  0.6380  0.6380
# Azerbaijan              0.0102  0.0102  0.0102  0.0102  0.0102  0.0102
# Bahamas                    NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
esta_na_ue=[]
for pais in d1["country"]:
    if pais in paises_ue:
        esta_na_ue.append('sim')
    else:
        esta_na_ue.append('não')
income["Está na UE"]=esta_na_ue
income
# Out:
#                           1801    1802    1803    1804    1805    1806  \
# country
# Afghanistan                NaN     NaN     NaN     NaN     NaN     NaN
# Albania                 0.4180  0.4180  0.4180  0.4180  0.4180  0.4180
# Algeria                 0.3560  0.3560  0.3560  0.3560  0.3560  0.3560
# Andorra                 0.1660  0.1660  0.1660  0.1660  0.1660  0.1660
# Angola                  0.4250  0.4250  0.4250  0.4250  0.4250  0.4250
# Antigua and Barbuda        NaN     NaN     NaN     NaN     NaN     NaN
# Argentina                  NaN     NaN     NaN     NaN     NaN     NaN
# Armenia                    NaN     NaN     NaN     NaN     NaN     NaN
# Australia              -0.0331 -0.0331 -0.0332 -0.0329 -0.0330 -0.0330
# Austria                 0.6380  0.6380  0.6380  0.6380  0.6380  0.6380
# Azerbaijan              0.0102  0.0102  0.0102  0.0102  0.0102  0.0102
# Bahamas                    NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
incomep=income.loc[["Germany","United Kingdom", "Greece", "France", "Canada", "Brazil", "China", "Mexico"]]
# incomep=incomep.transpose()
incomep.head()
# Out:
#                  1801   1802   1803   1804   1805   1806   1807   1808   1809  \
# country
# Germany         1.120  1.120  1.120  1.120  1.120  1.120  1.120  1.120  1.120
# United Kingdom  1.490  1.580 -2.000 -0.218  5.830 -0.579  6.410 -4.710  3.090
# Greece          0.520  0.520  0.520  0.520  0.520  0.520  0.520  0.520  0.520
# France          0.729  0.729  0.729  0.729  0.729  0.729  0.729  0.729  0.729
# Canada          1.810  1.810  1.810  1.810  1.810  1.810  1.810  1.810  1.810
#
#                  1810     ...       2005  2006  2007   2008  2009  2010  \
# country                   ...
# Germany         1.120     ...      0.798  4.01  3.49  0.926 -4.87  4.04
# United Kingdom  6.450     ...      1.950  2.58  3.39 -1.160 -4.39  1.75
# Greece          0.520     ...      4.130  5.63  3.64 -1.490 -3.14 -4.94
# France          0.729     ...      1.130  2.38  2.24 -0.060 -3.12  1.73
# Canada          1.810     ...      3.210  2.70  2.08  0.996 -2.98  2.98
#
# ...

# %%
groth_c=incomep.iloc[:, 149:200].transpose()
groth_c.head()
# Out:
# country  Germany  United Kingdom  Greece  France  Canada  Brazil  China  \
# 1950       18.90           3.290  -1.150    8.12   5.270   10.60   3.44
# 1951        8.91           2.740   8.970    5.19   6.290    5.25  12.70
# 1952        8.83          -0.118   0.764    2.25   6.820    7.68  11.90
# 1953        8.36           3.800  13.800    2.70   4.670    4.93  12.70
# 1954        7.60           4.080   3.310    5.16  -0.952    8.04   2.88
#
# country  Mexico
# 1950     12.200
# 1951      7.470
# 1952      3.900
# 1953      0.288
# 1954     10.500

# %%
world=income
world_gdp=world.iloc[:, 149:200].mean()
world_gdp.head()
# Out:
# 1950    4.559428
# 1951    4.400804
# 1952    4.076319
# 1953    5.558495
# 1954    5.194304
# dtype: float64

# %%
plt.plot(groth_c["United Kingdom"], label="UK")
plt.plot(world_gdp, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(groth_c["Germany"], label="Alemanha")
plt.plot(world_gdp, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(groth_c["Greece"], label="Grécia")
plt.plot(world_gdp, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(groth_c["France"], label="França")
plt.plot(world_gdp, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(groth_c["Brazil"], label="Brasil")
plt.plot(world_gdp, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(groth_c["Mexico"], label="Mexico")
plt.plot(world_gdp, label="world")
plt.grid()
plt.legend()

# %%
plt.plot(groth_c["Canada"], label="Canada")
plt.plot(world_gdp, label="world")
plt.grid()
plt.legend()

# %%
uk=groth_c["United Kingdom"]-world_gdp
plt.plot(uk)

# %%
germany=groth_c["Germany"]-world_gdp
plt.plot(germany)

# %%
greece=groth_c["Greece"]-world_gdp
plt.plot(greece)

# %%
france=groth_c["France"]-world_gdp
plt.plot(france)

# %%
plt.boxplot([france.iloc[0:9], france.iloc[9:]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x127c85978>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x127c910b8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x127c85828>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x127c91748>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x127c91a90>,
# ...
#  'means': []}

# %%
plt.boxplot([germany.iloc[0:9], germany.iloc[9:]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x127ed5be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x127edf320>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x127ed5a90>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x127edf9b0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x127edfcf8>,
# ...
#  'means': []}

# %%
plt.boxplot([uk.iloc[0:9], uk.iloc[9:]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x127f579b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x127f600f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x127f57860>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x127f60780>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x127f60ac8>,
# ...
#  'means': []}

# %%
plt.boxplot([greece.iloc[0:9], greece.iloc[9:]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1281e2828>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1281e2f28>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1281e26d8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1281ec5f8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1281ec940>,
# ...
#  'means': []}
